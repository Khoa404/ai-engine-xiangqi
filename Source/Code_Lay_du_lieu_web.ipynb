type=all&start=1&ngames=10000',
    'https://www.clubxiangqi.com/vi/xqrecord.php?F=xqrecord&record_name=MGM&type=all&start=1&ngames=10000',
    'https://www.clubxiangqi.com/vi/xqrecord.php?F=xqrecord&record_name=Wittenberg&type=all&start=1&ngames=10000'
    # Thêm các URL nguồn khác tại đây
]

# Lấy danh sách liên kết từ tất cả các nguồn
lien_ket = []
for url in nguon_urls:
    try:
        r = requests.get(url)
        r.raise_for_status()  # Kiểm tra lỗi HTTP
        xuly = BeautifulSoup(r.text, 'html.parser')
        # Lọc các liên kết có tiêu đề chứa "WXF notation" hoặc "Xem WXF"
        du_lieu = xuly.find_all('a', title=lambda x: x and ("WXF notation" in x or "Xem WXF" in x))
        lien_ket_nguon = ['https://www.clubxiangqi.com/' + item.get('href') for item in du_lieu]
        print(f"Đã lấy {len(lien_ket_nguon)} liên kết từ {url}")
        lien_ket.extend(lien_ket_nguon)
    except Exception as e:
        print(f"Lỗi khi lấy danh sách liên kết từ {url}: {str(e)}")

# Tập hợp để theo dõi các ID đã xử lý
id_da_xu_ly = set()

# Xử lý từng liên kết
for link in lien_ket:
    try:
        # Lấy ID ván cờ từ URL
        id_van_co = link.split('ID=')[1].split('&')[0]

        # Kiểm tra xem ID đã được xử lý chưa
        if id_van_co in id_da_xu_ly:
            continue  # Bỏ qua nếu ID đã được xử lý

        # Thêm ID vào tập hợp đã xử lý
        id_da_xu_ly.add(id_van_co)

        # Gửi yêu cầu đến trang ván cờ
        phan_hoi = requests.get(link)
        phan_hoi.raise_for_status()  # Kiểm tra lỗi HTTP
        soup = BeautifulSoup(phan_hoi.text, 'html.parser')

        # Tìm nội dung thẻ pre
        noi_dung_pre = soup.find('pre')
        if noi_dung_pre and noi_dung_pre.text.strip():  # Kiểm tra thẻ pre tồn tại và có nội dung
            noi_dung = noi_dung_pre.text

            # Trích xuất RESULT và START{...}END
            result_match = re.search(r'RESULT\s+[0-9.-]+', noi_dung)
            moves_match = re.search(r'START\{[\s\S]*?\}END', noi_dung)

            # Chỉ tạo tệp nếu cả hai phần đều tồn tại
            if result_match and moves_match:
                ket_qua = result_match.group(0)
                nuoc_di = moves_match.group(0)

                # Tạo tên tệp sử dụng ID ván cờ
                ten_tep = os.path.join(thu_muc_dau_ra, f"van_co_{id_van_co}.txt")

                # Lưu nội dung vào tệp
                with open(ten_tep, 'w', encoding='utf-8') as f:
                    f.write(ket_qua + "\n")
                    f.write(nuoc_di)
                print(f"Đã lưu ván cờ {id_van_co} vào {ten_tep}")
        # Nếu thiếu thẻ pre, thẻ pre rỗng, hoặc thiếu một trong hai phần, bỏ qua

    except Exception as e:
        print(f"Lỗi khi xử lý {link}: {str(e)}")

# Nén thư mục van_co_tuong thành file .zip
shutil.make_archive('/content/van_co_tuong', 'zip', thu_muc_dau_ra)
print("Đã nén thư mục van_co_tuong thành van_co_tuong.zip")

# Tải file .zip về máy cục bộ
files.download('/content/van_co_tuong.zip')

print(f"Hoàn tất xử lý. File van_co_tuong.zip đã được tải về máy.")
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Đã lưu ván cờ 87450538 vào /content/van_co_tuong/van_co_87450538.txt
# Đã lưu ván cờ 87450207 vào /content/van_co_tuong/van_co_87450207.txt
# Đã lưu ván cờ 87450101 vào /content/van_co_tuong/van_co_87450101.txt
# Đã lưu ván cờ 87450016 vào /content/van_co_tuong/van_co_87450016.txt
# Đã lưu ván cờ 87437818 vào /content/van_co_tuong/van_co_87437818.txt
# Đã lưu ván cờ 87437700 vào /content/van_co_tuong/van_co_87437700.txt
# Đã lưu ván cờ 87437575 vào /content/van_co_tuong/van_co_87437575.txt
# Đã lưu ván cờ 87437524 vào /content/van_co_tuong/van_co_87437524.txt
# Đã lưu ván cờ 87437370 vào /content/van_co_tuong/van_co_87437370.txt
# Đã lưu ván cờ 87436314 vào /content/van_co_tuong/van_co_87436314.txt
# Đã lưu ván cờ 87428333 vào /content/van_co_tuong/van_co_87428333.txt
# Đã lưu ván cờ 87420031 vào /content/van_co_tuong/van_co_87420031.txt
# Đã lưu ván cờ 87419884 vào /content/van_co_tuong/van_co_87419884.txt
# ...
