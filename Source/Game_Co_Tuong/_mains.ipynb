# %%
# tự động reload các module khi có thay đổi
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('D:/AI/SIC/Final_project/CoTuong/Co_Tuong')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of ai_minimax failed: Traceback (most recent call last):
#   File "d:\AI\python-3.11.9\Lib\site-packages\IPython\extensions\autoreload.py", line 280, in check
#     elif self.deduper_reloader.maybe_reload_module(m):
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\AI\python-3.11.9\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 533, in maybe_reload_module
#     new_source_code = f.read()
#                       ^^^^^^^^
#   File "d:\AI\python-3.11.9\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 69: character maps to <undefined>
# ]

# %% [markdown]
# # Trò Chơi Cờ Tướng
#
# Đây là chương trình chính để chạy trò chơi cờ tướng, cung cấp menu với các lựa chọn:
# - **1. Người vs Người**: Chơi cờ tướng giữa hai người chơi.
# - **2. Người vs Máy**: Người chơi Đỏ, máy chơi Đen.
# - **3. Máy vs Máy**: Hai AI đấu với nhau.
# - **4. Phát lại ván cờ**: Xem lại ván cờ từ file lịch sử.
# - **5. Thoát**: Kết thúc chương trình.
# - **6. Gợi ý nước đi**: Nhận diện bàn cờ từ ảnh và gợi ý nước đi cho Đỏ hoặc Đen.
#
# ## Kiểm tra
# - file mô hình YOLO nhận diện quân cờ (`best.pt`).
# - Cài đặt thư viện: `pip install pillow numpy matplotlib ultralytics inference-sdk`.

# %%
import numpy as np
from game_player_vs_player import game_player_vs_player
from game_player_vs_ai import game_player_vs_ai
from game_ai_vs_ai import game_ai_vs_ai
from game_replay import replay_game
from game_suggest_move import suggest_move

def main():
    """
    Hàm chính để chạy trò chơi cờ tướng.
    Hiển thị menu và xử lý các lựa chọn người dùng.
    """
    while True:
        # Hiển thị menu chính
        print("\n=== Trò Chơi Cờ Tướng ===")
        print("1. Người vs Người")
        print("2. Người vs Máy (Người chơi Đỏ, Máy chơi Đen)")
        print("3. Máy vs Máy")
        print("4. Phát lại ván cờ")
        print("5. Thoát")
        print("6. Gợi ý nước đi")
        print("==========================")
        
        choice = input("Nhập lựa chọn của bạn (1-6): ")
        
        if choice == '1':
            print("\nBắt đầu chế độ Người vs Người...")
            game_player_vs_player()
        elif choice == '2':
            print("\nBắt đầu chế độ Người vs Máy...")
            game_player_vs_ai()
        elif choice == '3':
            print("\nBắt đầu chế độ Máy vs Máy...")
            game_ai_vs_ai()
        elif choice == '4':
            print("\nBắt đầu chế độ Phát lại ván cờ...")
            replay_game()
        elif choice == '5':
            print("\nThoát trò chơi!")
            break
        elif choice == '6':
            suggest_move()
        else:
            print("\nLựa chọn không hợp lệ! Vui lòng chọn từ 1 đến 6.")

if __name__ == "__main__":
    main()
# Out:
# === Trò Chơi Cờ Tướng ===
# 1. Người vs Người
# 2. Người vs Máy (Người chơi Đỏ, Máy chơi Đen)
# 3. Máy vs Máy
# 4. Phát lại ván cờ
# 5. Thoát
# 6. Gợi ý nước đi
# ...
#
# Bắt đầu chế độ Người vs Máy...
#      0  1  2  3  4  5  6  7  8
#
# 0 |  x  m  t  s  tg s  t  m  x  |
# 1 |  .  .  .  .  .  .  .  .  .  |
# 2 |  .  p  .  .  .  .  .  p  .  |
# 3 |  b  .  b  .  b  .  b  .  b  |
# 4 |  .  .  .  .  .  .  .  .  .  |
#   |   ~~  ~~  ~~  ~~  ~~  ~~    |
# 5 |  .  .  .  .  .  .  .  .  .  |
# 6 |  B  .  B  .  B  .  B  .  B  |
# 7 |  .  P  .  .  .  .  .  P  .  |
# 8 |  .  .  .  .  .  .  .  .  .  |
# 9 |  X  M  T  S  TG S  T  M  X  |
#
#
# Lượt của Đỏ (người chơi)
#
# Ok!! Nước đi (7, 1) đến (7, 4) hợp lệ.
#
# Ok!! Nước đi (7, 1) đến (7, 4) hợp lệ.
#
# Lịch sử nước đi:
# Đỏ di chuyển P từ (7, 1) đến (7, 4)
#      0  1  2  3  4  5  6  7  8
#
# 0 |  x  m  t  s  tg s  t  m  x  |
# 1 |  .  .  .  .  .  .  .  .  .  |
# 2 |  .  p  .  .  .  .  .  p  .  |
# 3 |  b  .  b  .  b  .  b  .  b  |
# ...
